# %% [markdown]
# # This file consists of basic Python functions on Strings

# %%
name = 'Sampy'
functionNumber = 1

# %%
print(f'Welcome to the {functionNumber}st Python class of {name}')
# Out:
# Welcome to the 1st Python class of Sampy

# %%
firstGoodList = [1, 2, 3, 4, 5]
firstMixedList = [1, 2, 3, 'a', 'b', 'c']

# %%
firstGoodList **2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-ab01ee094546> in <module>
# ----> 1 firstGoodList **2
#
# NameError: name 'firstGoodList' is not defined

# %%
def main1():
  print("Hello World!")

# The variable '__name__' is a special variable and is defaultly assigned the value '__main__' when the source file 
# that is executing is the main program
if __name__== "__main__":
  main1()

print("Guru99")
# Out:
# Hello World!
# Guru99

# %%
def main():
  print("Hello World!")

tempVar = 'Hi'
if tempVar == "Hi":
  main()

print("Guru99")
# Out:
# Hello World!
# Guru99

# %%
a = "Sampy"
b = 1
print (a+str(b))
# Out:
# Sampy1

# %%
a = "Sampy"
b = 1
print (a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-109035291005> in <module>
#       1 a = "Sampy"
#       2 b = 1
# ----> 3 print (a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
myStr = "Sampy Here"
print(myStr[2:7])
print(myStr[6])
print("a" in myStr)
print("x" in myStr)
print("x" not in myStr)
print(myStr*2)
print(myStr[:])
print(myStr[:3])
print(myStr[2:])
# Out:
# mpy H
# H
# True
# False
# True
# Sampy HereSampy Here
# Sampy Here
# Sam
# mpy Here

# %%
print(myStr.replace('Here', 'Everywhere'))
print(myStr)
print(myStr.lower())
print(myStr.upper())
print(myStr.lower().capitalize())
print(myStr.capitalize())
print(myStr)
# Out:
# Sampy Everywhere
# Sampy Here
# sampy here
# SAMPY HERE
# Sampy here
# Sampy here
# Sampy Here

# %%
print(":".join(myStr))
print("".join(reversed(myStr)))
print(myStr.split(" "))
print(myStr.split("e"))
# Out:
# S:a:m:p:y: :H:e:r:e
# ereH ypmaS
# ['Sampy', 'Here']
# ['Sampy H', 'r', '']

# %%
word="guru99 career guru99"
print(word.split('r'))
# Out:
# ['gu', 'u99 ca', 'ee', ' gu', 'u99']

# %%
def firstFunc( xyz ):
    abc = "12345"
    print(abc)
    print(xyz)
    return

firstFunc("4321")
# Out:
# 12345
# 4321

# %%
def firstFunc( xyz ):
    abc = "12345"
    print(abc)
    print(xyz)

a = 5
if a == 5:
    firstFunc("4321")
# Out:
# 12345
# 4321

# %%
t1 = [4, 2, 3]
t2 = [2, 3, 5]
if t1 > t2:
    print("Hi there")
else:
    print("Bye")
# Out:
# Hi there

# %%
t1 = [2, 2, 3]
t2 = [2, 3, 5]
if t1 > t2:
    print("Hi there")
else:
    print("Bye")
# Out:
# Bye

# %%
t1 = [2, 2, 3]
t2 = [2, 2, 3]
if t1 > t2:
    print("Hi there")
else:
    print("Bye")
# Out:
# Bye
